# %% [markdown]
# #### Import the all Required Libraries

# %%
import os
import shutil
import glob
from tqdm import tqdm

# %% [markdown]
# gender: 0 - male 1 - famale
#
# glasses: 0 - no 1 - yes
#
# eye state: 0 - close 1 - open
#
# reflections: 0 - none 1 - low 2 - high
#
# ighting conditions/image quality: 0 - bad 1 - good
#
# sensor type: 01 - RealSense SR300 640x480 02 - IDS Imaging, 1280x1024 03 - Aptina Imagin 752x480
#
# example: s001_00123_0_0_0_0_0_01.png

# %% [markdown]
# #### Imports the data sets (Images)

# %%
DIRECTORY= r"C:\Users\satee\My_Final_Year_Projects\Driver's_Drowsiness_Detection\Datasets" #File Location

#Loopiong the directory to saperate the closed eyes and opened eyes images
for dirpath, dirname, filenames in os.walk(DIRECTORY):
    for i in tqdm([f for f in filenames if f.endswith('.png')]):
        if i.split('_')[4]=='0':
            shutil.copy(src=dirpath+'/'+i, dst=r"C:\Users\satee\My_Final_Year_Projects\Driver's_Drowsiness_Detection\After_saperation\Closed_eyes")
        elif i.split('_')[4]=='1':
            shutil.copy(src=dirpath+'/'+i, dst=r"C:\Users\satee\My_Final_Year_Projects\Driver's_Drowsiness_Detection\After_saperation\Opened_eyes")
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 10257/10257 [01:44<00:00, 98.62it/s]
